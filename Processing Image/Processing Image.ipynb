# %%
### Importing the image module from matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
### Loading the image
img = mpimg.imread('Aditya Kumar.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape ### (height, width, color channels)
# Out:
# (1280, 960, 3)

# %%
### displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %%
### Resizing the image using Pillow
from PIL import Image

img_pil = Image.open('Aditya Kumar.jpg')
img_resized = img_pil.resize((200, 200)) # Resizing to 200x200 pixels

img_resized.save('Aditya Kumar Resized.jpg') # Saving the resized image

# %%
### Displaying the resized image using matplotlib
resized_img = mpimg.imread('Aditya Kumar Resized.jpg')
img_resized_plot = plt.imshow(resized_img)
plt.show()

# %%
resized_img.shape
# Out:
# (200, 200, 3)

# %%
### OpenCV for image processing

#### Converting the image to grayscale
import cv2

# %%
img = cv2.imread('Aditya Kumar.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1280, 960, 3)

# %%
gray_scale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(gray_scale_img)
# Out:
# numpy.ndarray

# %%
gray_scale_img.shape
# Out:
# (1280, 960)

# %%
### Displaying the image using matplotlib
plt.imshow(gray_scale_img, cmap='gray')

# %%
### Saving the grayscale image
cv2.imwrite('Aditya Kumar Grayscale.jpg', gray_scale_img)
# Out:
# True
